# %%
#import lib:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading data:
df=pd.read_csv('https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv')
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
# 5    906539         B        11.57         19.04           74.20      409.7
# 6    925291         B        11.51         23.93           74.52      403.5
# 7     87880         M        13.81         23.75           91.56      597.8
# 8    862989         B        10.49         19.29           67.41      336.1
# 9     89827         B        11.06         14.96           71.49      373.9
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# ...

# %%
#here we can drop the columns: 'id'(not significant)
df.drop(['id'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'points_mean', 'symmetry_mean', 'dimension_mean', 'radius_se',
#        'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'points_se', 'symmetry_se',
#        'dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst',
#        'area_worst', 'smoothness_worst', 'compactness_worst',
#        'concavity_worst', 'points_worst', 'symmetry_worst', 'dimension_worst'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %%
#Check the descriptive statistics of the dataset
df.describe().T
# Out:
#                    count        mean         std         min         25%  \
# radius_mean        569.0   14.127292    3.524049    6.981000   11.700000
# texture_mean       569.0   19.289649    4.301036    9.710000   16.170000
# perimeter_mean     569.0   91.969033   24.298981   43.790000   75.170000
# area_mean          569.0  654.889104  351.914129  143.500000  420.300000
# smoothness_mean    569.0    0.096360    0.014064    0.052630    0.086370
# compactness_mean   569.0    0.104341    0.052813    0.019380    0.064920
# concavity_mean     569.0    0.088799    0.079720    0.000000    0.029560
# points_mean        569.0    0.048919    0.038803    0.000000    0.020310
# symmetry_mean      569.0    0.181162    0.027414    0.106000    0.161900
# dimension_mean     569.0    0.062798    0.007060    0.049960    0.057700
# radius_se          569.0    0.405172    0.277313    0.111500    0.232400
# texture_se         569.0    1.216853    0.551648    0.360200    0.833900
# ...

# %%
#Visualize some of those columns and find out if you observe any pattern
##visualizing and analysing the realtionship between radius_mean,radius_se,radius_worst
sns.pairplot(data=df,vars=['radius_mean','radius_se','radius_worst'],diag_kind='kde',kind='reg')

# %%
sns.pairplot(data=df,vars=['area_mean','perimeter_mean','dimension_mean'],diag_kind='kde',kind='reg')

# %%
sns.pairplot(data=df,vars=['texture_mean','concavity_mean','points_mean'],diag_kind='kde',kind='reg')

# %% [markdown]
# ## Observations:
# Here it can be clearly observed that the dataset consists of the 'mean','se' and 'worst' values of the
# following elements of TUMOR CELLS:
# 1. Radius 2. Texture 3. Perimeter 4. Area 5. Smoothness
# 6. Compactness 7. Concavity 8. Points 9. Symmetry 10. Dimension
#
# ### Patterns Observed:
#
# ##### area-dimension-perimeter:
# 1) are strongly corelated
# 2) are negatively corellated
# 3) they have high effect on each other
# ##### texture-concavity-points:
# 1) All three are positively correlated
# 2) texture-concavity, points-texture have a weak correlation
# 3) concavity-points have a strong correlation
#
# texture has only little affect on concavity and points whereas point-concavity have high effect on each other

# %%
#Find the correlation in the data and visualize it 
###Correlation:
df.corr()
# Out:
#                    radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean           1.000000      0.323782        0.997855   0.987357
# texture_mean          0.323782      1.000000        0.329533   0.321086
# perimeter_mean        0.997855      0.329533        1.000000   0.986507
# area_mean             0.987357      0.321086        0.986507   1.000000
# smoothness_mean       0.170581     -0.023389        0.207278   0.177028
# compactness_mean      0.506124      0.236702        0.556936   0.498502
# concavity_mean        0.676764      0.302418        0.716136   0.685983
# points_mean           0.822529      0.293464        0.850977   0.823269
# symmetry_mean         0.147741      0.071401        0.183027   0.151293
# dimension_mean       -0.311631     -0.076437       -0.261477  -0.283110
# radius_se             0.679090      0.275869        0.691765   0.732562
# texture_se           -0.097317      0.386358       -0.086761  -0.066280
# ...

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(data=df.corr(),annot=True,fmt='.3f')

# %%
#Visualize the frequency of the output categories
df.diagnosis.value_counts().plot(kind='bar',color='purple')

# %%
#Apply the KNN Algorithm to the dataset without applying scaling operation
#and try to compare the results before scaling and after scaling.
X=df.drop(['diagnosis'],axis=1)
y=df.diagnosis

#splitting the data:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# ### Before SCALING:

# %%
#first let us find the optimum K-value using ELBOW method:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
score=[]
for k in range(1,20):
    knn_model=KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train,y_train)
    pred_test=knn_model.predict(X_test)
    score.append(accuracy_score(y_test,pred_test))

# %%
#plotting the score:
plt.plot(range(1,20),score,marker='^')

# %%
#optimum value for K is 11
final_model=KNeighborsClassifier(n_neighbors=11,metric='euclidean')
final_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=11, p=2,
#                      weights='uniform')

# %%
y_train_pred=final_model.predict(X_train)
y_test_pred=final_model.predict(X_test)
#lets keep it like this and compare both the calssification reports in the end
#just for more detail between before and after scaling

# %% [markdown]
# ## After SCALING:

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
scaled_X_train=pd.DataFrame(data=ss.fit_transform(X_train),columns=X_train.columns)
scaled_X_test=pd.DataFrame(data=ss.fit_transform(X_test),columns=X_test.columns)

# %%
#first let us find the optimum K-value using ELBOW method:
score1=[]
for k in range(1,20):
    scaled_knn_model=KNeighborsClassifier(n_neighbors=k)
    scaled_knn_model.fit(scaled_X_train,y_train)
    scaled_pred_test=scaled_knn_model.predict(scaled_X_test)
    score1.append(accuracy_score(y_test,scaled_pred_test))

# %%
#plotting the score:
plt.plot(range(1,20),score1,marker='o')

# %%
#optimum value for K is 8
scaled_final_model=KNeighborsClassifier(n_neighbors=8,metric='euclidean')
scaled_final_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                      weights='uniform')

# %%
scaled_y_train_pred=scaled_final_model.predict(scaled_X_train)
scaled_y_test_pred=scaled_final_model.predict(scaled_X_test)

# %% [markdown]
# ## Classification Reports for Train & Test data:
# #### Before scaling:

# %%
print('CLASSIFICATION REPORT before SCALING:\n')
print('on TRAINING DATA:\n')
print(classification_report(y_train_pred,y_train))
print('\non TESTING DATA:\n')
print(classification_report(y_test_pred,y_test))
print('\nCLASSIFICATION REPORT after SCALING:\n')
print('on TRAINING DATA:\n')
print(classification_report(scaled_y_train_pred,y_train))
print('\non TESTING DATA:\n')
print(classification_report(scaled_y_test_pred,y_test))
# Out:
# CLASSIFICATION REPORT before SCALING:
#
# on TRAINING DATA:
#
#               precision    recall  f1-score   support
#
#            B       0.96      0.94      0.95       257
#            M       0.89      0.94      0.91       141
#
#     accuracy                           0.94       398
#    macro avg       0.93      0.94      0.93       398
# weighted avg       0.94      0.94      0.94       398
#
#
# on TESTING DATA:
#
#               precision    recall  f1-score   support
#
#            B       0.98      0.93      0.95       113
#            M       0.88      0.97      0.92        58
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.95      0.94       171
# weighted avg       0.95      0.94      0.94       171
#
#
# CLASSIFICATION REPORT after SCALING:
#
# on TRAINING DATA:
#
#               precision    recall  f1-score   support
#
#            B       1.00      0.95      0.97       263
# ...

# %% [markdown]
# ## Observations on performing applying the KNN algo before & after scaling the data:
# `
# Before scaling--> the Accuracy of the model was 94%
# After scaling --> the accuracy of the model was 97%
# Now, that might not look like much of an increase in the accuracy of the model, some might even think that it doesn't make much difference but, slightest change in accuracy of machine learning models is considered quite significant.
# That being said, here, we can say that the model that was trained on scaled values worked much better than the one that was trained on non-uniform values.
# This indicates that, distance based algorithms like KNN produce better outcomes when provide with scalled data, rather than test data.
# `
