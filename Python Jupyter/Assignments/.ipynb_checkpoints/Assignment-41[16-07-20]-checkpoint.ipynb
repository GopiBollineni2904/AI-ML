# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("all_stocks_5yr.csv")
#df.sort_values('date',ascending=True,inplace=True)
df.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619040 entries, 0 to 619039
# Data columns (total 7 columns):
# date      619040 non-null object
# open      619029 non-null float64
# high      619032 non-null float64
# low       619032 non-null float64
# close     619040 non-null float64
# volume    619040 non-null int64
# Name      619040 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (619040, 7)

# %%
df.Name.value_counts()
# Out:
# COP     1259
# YUM     1259
# ADS     1259
# SO      1259
# CMG     1259
#         ...
# DXC      215
# BHGE     152
# BHF      143
# DWDP     109
# APTV      44
# Name: Name, Length: 505, dtype: int64

# %%
df_gpc=df[df.Name=='GPC']
df_gpc.head()
# Out:
#               date   open   high    low  close  volume Name
# 252542  2013-02-08  69.57  69.99  69.57  69.92  533092  GPC
# 252543  2013-02-11  69.92  70.11  69.47  69.89  417443  GPC
# 252544  2013-02-12  69.87  70.23  69.84  70.19  659367  GPC
# 252545  2013-02-13  70.20  70.62  69.89  70.54  600947  GPC
# 252546  2013-02-14  70.55  70.87  70.36  70.79  581533  GPC

# %%
df_gpc.shape
# Out:
# (1259, 7)

# %%
df_gpc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1259 entries, 252542 to 253800
# Data columns (total 7 columns):
# date      1259 non-null object
# open      1259 non-null float64
# high      1259 non-null float64
# low       1259 non-null float64
# close     1259 non-null float64
# volume    1259 non-null int64
# Name      1259 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 78.7+ KB

# %%
x = []
y = []
for i  in range(df_gpc.shape[0]-7-1):
    x.append(df_gpc['high'][i:i+7])
    y.append(df_gpc['high'][252542+i+7])
print(x[:2])
# Out:
# [252542    69.99
# 252543    70.11
# 252544    70.23
# 252545    70.62
# 252546    70.87
# 252547    71.44
# 252548    70.91
# Name: high, dtype: float64, 252543    70.11
# 252544    70.23
# 252545    70.62
# 252546    70.87
# 252547    71.44
# 252548    70.91
# 252549    69.64
# Name: high, dtype: float64]

# %%
x=np.array(x)

# %%
df1=pd.DataFrame(x,columns=['d1','d2','d3','d4','d5','d6','d7'])
df1.head()
# Out:
#       d1     d2     d3     d4     d5     d6     d7
# 0  69.99  70.11  70.23  70.62  70.87  71.44  70.91
# 1  70.11  70.23  70.62  70.87  71.44  70.91  69.64
# 2  70.23  70.62  70.87  71.44  70.91  69.64  68.98
# 3  70.62  70.87  71.44  70.91  69.64  68.98  69.58
# 4  70.87  71.44  70.91  69.64  68.98  69.58  69.93

# %%
df1['d8']=y
df1.head()
# Out:
#       d1     d2     d3     d4     d5     d6     d7     d8
# 0  69.99  70.11  70.23  70.62  70.87  71.44  70.91  69.64
# 1  70.11  70.23  70.62  70.87  71.44  70.91  69.64  68.98
# 2  70.23  70.62  70.87  71.44  70.91  69.64  68.98  69.58
# 3  70.62  70.87  71.44  70.91  69.64  68.98  69.58  69.93
# 4  70.87  71.44  70.91  69.64  68.98  69.58  69.93  69.42

# %%
df1.shape
# Out:
# (1251, 8)

# %%
x_train=df1.iloc[:1000,:7]
x_test=df1.iloc[1000:,:7]
y_train=df1['d8'][:1000]
y_test=df1['d8'][1000:]
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 7)
# (251, 7)
# (1000,)
# (251,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_train_sc=pd.DataFrame(sc.transform(x_train),columns=x_train.columns)
x_test_sc=pd.DataFrame(sc.transform(x_test),columns=x_test.columns)
x_train_sc.describe()
# Out:
#                  d1            d2            d3            d4            d5  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   2.788880e-16  3.895773e-16  2.224887e-16  1.613154e-15 -1.114664e-15
# std    1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00
# min   -2.525342e+00 -2.534887e+00 -2.544360e+00 -2.553732e+00 -2.562999e+00
# 25%   -7.462226e-01 -7.504773e-01 -7.528770e-01 -7.562034e-01 -7.609524e-01
# 50%   -1.314048e-01 -1.344606e-01 -1.375483e-01 -1.394377e-01 -1.405654e-01
# 75%    9.108578e-01  9.119030e-01  9.119479e-01  9.120439e-01  9.124433e-01
# max    2.407993e+00  2.410548e+00  2.412954e+00  2.415158e+00  2.417519e+00
#
#                  d6            d7
# count  1.000000e+03  1.000000e+03
# mean   1.216582e-15 -7.787104e-16
# std    1.000500e+00  1.000500e+00
# min   -2.572049e+00 -2.580626e+00
# 25%   -7.659756e-01 -7.699067e-01
# 50%   -1.429550e-01 -1.440447e-01
# 75%    9.119390e-01  9.117654e-01
# max    2.419599e+00  2.421271e+00

# %%
import tensorflow.keras as keras

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,LSTM
model=Sequential()
model.add(LSTM(256,input_shape=(7,1)))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               264192
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 264,449
# Trainable params: 264,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mse')

# %%
x_train_sc = x_train_sc.values.reshape(1000,7,1)
x_test_sc = x_test_sc.values.reshape(251,7,1)

# %%
history = model.fit(x_train_sc,y_train,epochs=100,validation_data=(x_test_sc,y_test))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 2s 50ms/step - loss: 7151.9790 - val_loss: 4768.3335
# Epoch 2/100
# 32/32 [==============================] - 1s 32ms/step - loss: 3745.5208 - val_loss: 3378.4558
# Epoch 3/100
# 32/32 [==============================] - 1s 24ms/step - loss: 2682.6729 - val_loss: 2481.2148
# Epoch 4/100
# 32/32 [==============================] - 1s 26ms/step - loss: 1949.2046 - val_loss: 1823.6873
# Epoch 5/100
# 32/32 [==============================] - 1s 26ms/step - loss: 1406.9319 - val_loss: 1326.2523
# Epoch 6/100
# 32/32 [==============================] - 1s 24ms/step - loss: 1002.8500 - val_loss: 956.7756
# Epoch 7/100
# 32/32 [==============================] - 1s 25ms/step - loss: 708.4857 - val_loss: 680.9044
# Epoch 8/100
# 32/32 [==============================] - 1s 35ms/step - loss: 496.0732 - val_loss: 483.5783
# Epoch 9/100
# 32/32 [==============================] - 1s 35ms/step - loss: 347.8391 - val_loss: 342.6715
# Epoch 10/100
# 32/32 [==============================] - 1s 35ms/step - loss: 245.9562 - val_loss: 244.2245
# Epoch 11/100
# 32/32 [==============================] - 1s 36ms/step - loss: 177.5275 - val_loss: 176.3543
# Epoch 12/100
# 32/32 [==============================] - 1s 34ms/step - loss: 132.3723 - val_loss: 130.2624
# Epoch 13/100
# 32/32 [==============================] - 1s 33ms/step - loss: 104.5000 - val_loss: 99.2661
# Epoch 14/100
# 32/32 [==============================] - 1s 25ms/step - loss: 87.3402 - val_loss: 79.5366
# Epoch 15/100
# 32/32 [==============================] - 1s 26ms/step - loss: 77.0683 - val_loss: 65.9882
# Epoch 76/100
# 32/32 [==============================] - 1s 24ms/step - loss: 2.9627 - val_loss: 4.8191
# Epoch 77/100
# 32/32 [==============================] - 1s 23ms/step - loss: 3.0186 - val_loss: 4.8322
# Epoch 78/100
# 32/32 [==============================] - 1s 24ms/step - loss: 2.8631 - val_loss: 4.4902
# Epoch 79/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.8822 - val_loss: 6.0980
# Epoch 80/100
# 32/32 [==============================] - 1s 28ms/step - loss: 3.0331 - val_loss: 4.1162
# Epoch 81/100
# 32/32 [==============================] - 1s 27ms/step - loss: 2.6854 - val_loss: 4.3084
# Epoch 82/100
# 32/32 [==============================] - 1s 26ms/step - loss: 2.4788 - val_loss: 3.7604
# Epoch 83/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.4324 - val_loss: 4.4688
# Epoch 84/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.3539 - val_loss: 3.5236
# Epoch 85/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.1912 - val_loss: 3.3217
# Epoch 86/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.2930 - val_loss: 3.8197
# Epoch 87/100
# 32/32 [==============================] - 1s 27ms/step - loss: 2.4633 - val_loss: 3.1634
# Epoch 88/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.2268 - val_loss: 3.2389
# Epoch 89/100
# 32/32 [==============================] - 1s 27ms/step - loss: 2.1334 - val_loss: 3.5773
# Epoch 90/100
# 32/32 [==============================] - 1s 26ms/step - loss: 2.0867 - val_loss: 3.0326
# Epoch 91/100
# 32/32 [==============================] - 1s 24ms/step - loss: 1.8013 - val_loss: 2.8979
# Epoch 92/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.8318 - val_loss: 2.8795
# Epoch 93/100
# 32/32 [==============================] - 1s 24ms/step - loss: 1.9708 - val_loss: 3.0447
# Epoch 94/100
# 32/32 [==============================] - 1s 26ms/step - loss: 2.2114 - val_loss: 3.1110
# Epoch 95/100
# 32/32 [==============================] - 1s 25ms/step - loss: 1.8567 - val_loss: 2.8071
# Epoch 96/100
# 32/32 [==============================] - 1s 27ms/step - loss: 1.8004 - val_loss: 3.1137
# Epoch 97/100
# 32/32 [==============================] - 1s 25ms/step - loss: 1.8683 - val_loss: 2.7454
# Epoch 98/100
# 32/32 [==============================] - 1s 26ms/step - loss: 1.7585 - val_loss: 3.0070
# Epoch 99/100
# 32/32 [==============================] - 1s 27ms/step - loss: 1.8734 - val_loss: 2.5095
# Epoch 100/100
# 32/32 [==============================] - 1s 24ms/step - loss: 1.7055 - val_loss: 2.6133

# %%
tr_loss = history.history['loss']
val_loss = history.history['val_loss']
ep = list(range(1,101))
plt.plot(ep,tr_loss,color='r')
plt.plot(ep,val_loss,color='b')

# %%
model.predict(x_test_sc)
# Out:
# array([[ 97.646416],
#        [ 98.13665 ],
#        [ 98.8628  ],
#        [ 99.34989 ],
#        [ 99.74732 ],
#        [100.03942 ],
#        [100.39275 ],
#        [100.734604],
#        [100.93565 ],
#        [101.11114 ],
#        [100.15006 ],
#        [ 98.75616 ],
#        [ 97.74476 ],
#        [ 97.25099 ],
#        [ 96.567245],
#        [ 96.487724],
#        [ 96.53402 ],
#        [ 96.343155],
#        [ 95.606606],
#        [ 94.829506],
#        [ 94.070885],
#        [ 93.39429 ],
#        [ 93.10605 ],
#        [ 93.283066],
#        [ 93.61724 ],
#        [ 93.91329 ],
#        [ 94.202644],
#        [ 94.48762 ],
#        [ 94.63088 ],
#        [ 94.56313 ],
#        [ 94.04316 ],
#        [ 93.68959 ],
#        [ 93.466255],
#        [ 92.96104 ],
#        [ 92.80453 ],
#        [ 92.84811 ],
#        [ 93.03794 ],
#        [ 92.96597 ],
#        [ 92.58583 ],
#        [ 91.50501 ],
#        [ 90.80712 ],
#        [ 90.22728 ],
#        [ 89.87205 ],
#        [ 89.95644 ],
#        [ 89.994606],
#        [ 89.85953 ],
#        [ 89.57756 ],
#        [ 89.47176 ],
#        [ 89.64614 ],
#        [ 91.53606 ],
#        [ 92.47621 ],
#        [ 92.98144 ],
#        [ 93.447395],
#        [ 93.90618 ],
#        [ 93.826775],
#        [ 93.58579 ],
#        [ 93.397644],
#        [ 92.66076 ],
#        [ 91.98538 ],
#        [ 91.62081 ],
#        [ 91.652214],
#        [ 91.82044 ],
#        [ 92.103386],
#        [ 92.3579  ],
#        [ 92.40156 ],
#        [ 92.16111 ],
#        [ 91.69805 ],
#        [ 91.800766],
#        [ 91.686676],
#        [ 91.47272 ],
#        [ 91.52903 ],
#        [ 91.71064 ],
#        [ 91.9773  ],
#        [ 91.64644 ],
#        [ 91.02901 ],
#        [ 90.7868  ],
#        [ 91.67124 ],
#        [ 92.41171 ],
#        [ 92.52238 ],
#        [ 93.192116],
#        [ 93.90893 ],
#        [ 94.08889 ],
#        [ 93.689766],
#        [ 92.86295 ],
#        [ 92.07369 ],
#        [ 91.37495 ],
#        [ 91.707726],
#        [ 92.461205],
#        [ 93.53788 ],
#        [ 94.2726  ],
#        [ 94.905464],
#        [ 95.37977 ],
#        [ 94.464   ],
#        [ 92.91773 ],
#        [ 91.1974  ],
#        [ 90.30161 ],
#        [ 90.13471 ],
#        [ 90.445015],
#        [ 91.30262 ],
#        [ 91.77546 ],
#        [ 92.30005 ],
#        [ 92.87737 ],
#        [ 92.7286  ],
#        [ 90.77541 ],
#        [ 88.58111 ],
#        [ 86.95246 ],
#        [ 85.461845],
#        [ 84.469215],
#        [ 83.98491 ],
#        [ 83.84815 ],
#        [ 83.96345 ],
#        [ 84.02094 ],
#        [ 83.73234 ],
#        [ 83.80756 ],
#        [ 83.59632 ],
#        [ 83.128395],
#        [ 83.15348 ],
#        [ 83.264305],
#        [ 83.91549 ],
#        [ 84.515335],
#        [ 84.86404 ],
#        [ 84.73177 ],
#        [ 84.78837 ],
#        [ 84.773155],
#        [ 84.51596 ],
#        [ 84.342155],
#        [ 84.310524],
#        [ 83.96665 ],
#        [ 83.49132 ],
#        [ 83.10016 ],
#        [ 83.24757 ],
#        [ 82.857796],
#        [ 82.62289 ],
#        [ 82.70133 ],
#        [ 82.41064 ],
#        [ 82.5767  ],
#        [ 82.80962 ],
#        [ 82.88418 ],
#        [ 83.01834 ],
#        [ 83.33876 ],
#        [ 83.47145 ],
#        [ 83.19047 ],
#        [ 83.03103 ],
#        [ 83.1414  ],
#        [ 83.483315],
#        [ 84.075294],
#        [ 84.69612 ],
#        [ 84.85615 ],
#        [ 85.1497  ],
#        [ 85.66343 ],
#        [ 86.281425],
#        [ 86.61616 ],
#        [ 86.739525],
#        [ 86.664406],
#        [ 86.592865],
#        [ 86.67056 ],
#        [ 86.76241 ],
#        [ 86.750175],
#        [ 87.136696],
#        [ 91.023094],
#        [ 93.35752 ],
#        [ 94.44219 ],
#        [ 95.24064 ],
#        [ 95.80947 ],
#        [ 96.139854],
#        [ 96.0999  ],
#        [ 96.04499 ],
#        [ 95.918076],
#        [ 95.816246],
#        [ 95.73734 ],
#        [ 95.72607 ],
#        [ 95.76667 ],
#        [ 95.90385 ],
#        [ 96.10599 ],
#        [ 96.122765],
#        [ 96.42002 ],
#        [ 97.25424 ],
#        [ 95.60678 ],
#        [ 92.81492 ],
#        [ 90.83532 ],
#        [ 89.759224],
#        [ 88.58579 ],
#        [ 88.44929 ],
#        [ 88.72914 ],
#        [ 88.45385 ],
#        [ 88.15519 ],
#        [ 88.063065],
#        [ 88.1003  ],
#        [ 88.0689  ],
#        [ 87.86443 ],
#        [ 87.557625],
#        [ 86.922615],
#        [ 86.28649 ],
#        [ 85.94416 ],
#        [ 85.69222 ],
#        [ 86.14604 ],
#        [ 86.981834],
#        [ 86.72104 ],
#        [ 86.570015],
#        [ 86.37511 ],
#        [ 86.23694 ],
#        [ 86.39323 ],
#        [ 86.55567 ],
#        [ 87.004234],
#        [ 87.888664],
#        [ 89.56451 ],
#        [ 91.2491  ],
#        [ 92.35911 ],
#        [ 93.28071 ],
#        [ 94.162315],
#        [ 94.40479 ],
#        [ 94.29134 ],
#        [ 94.44356 ],
#        [ 94.480484],
#        [ 94.13163 ],
#        [ 93.7595  ],
#        [ 93.38528 ],
#        [ 93.10922 ],
#        [ 93.05696 ],
#        [ 93.23954 ],
#        [ 93.31306 ],
#        [ 93.67672 ],
#        [ 94.38811 ],
#        [ 95.06162 ],
#        [ 95.407234],
#        [ 95.615486],
#        [ 95.7641  ],
#        [ 96.24958 ],
#        [ 96.75668 ],
#        [ 97.43237 ],
#        [ 97.65739 ],
#        [ 98.01089 ],
#        [ 98.53231 ],
#        [ 99.02714 ],
#        [100.04386 ],
#        [101.19583 ],
#        [102.424095],
#        [103.01391 ],
#        [103.21149 ],
#        [103.37066 ],
#        [103.41776 ],
#        [103.536674],
#        [103.880745],
#        [104.11819 ],
#        [104.320305],
#        [104.4311  ],
#        [104.41767 ],
#        [104.27867 ],
#        [103.95455 ],
#        [103.68009 ],
#        [103.27246 ]], dtype=float32)

# %%
plt.plot(range(len(x_test_sc)),model.predict(x_test_sc).flat)
plt.plot(range(len(x_test_sc)),y_test)

# %%
x_test_sc[0].reshape(1,7,1)
# Out:
# array([[[0.94229206],
#         [0.98079554],
#         [1.0330317 ],
#         [0.93268549],
#         [0.98758045],
#         [1.02388317],
#         [1.01519041]]])

# %%
model.predict(x_test_sc[0].reshape(1,7,1))
# Out:
# array([[97.64639]], dtype=float32)

# %%
y_test[1000]
# Out:
# 99.07
