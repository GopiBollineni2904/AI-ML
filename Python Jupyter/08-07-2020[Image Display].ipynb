# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("color_image1.jpg")
print(img.shape)
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
#to display in diff color
plt.imshow(img[:,:,0])

# %%
#image in grayscale
plt.imshow(img[:,:,2],cmap='gray')

# %%
#part of image
plt.imshow(img[:,:120])
