# %% [markdown]
# # 10-06-2020

# %%
#Data analysis and Manipulation
import pandas as pd
#Numerical calculations and handling n dimensional arrays
import numpy as np
#visualization
import matplotlib.pyplot as plt
#visualization with different styles and advanced methods built on matplotlib
import seaborn as sns
#display the figure in the output cell in jupyter notebook
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips['total_bill'].hist()

# %%
plt.hist(tips['total_bill'],bins=5)
# Out:
# (array([ 49., 119.,  50.,  19.,   7.]),
#  array([ 3.07 , 12.618, 22.166, 31.714, 41.262, 50.81 ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(tips['tip'],bins=10)
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## SEABORN:

# %%
sns.distplot(tips['total_bill'],kde=False) #distribution plot

# %%
sns.relplot('total_bill',"tip",data=tips)  #relational plot

# %%
sns.relplot('total_bill',"tip",data=tips,hue='smoker') #for distinguished plots

# %%
sns.relplot('total_bill',"tip",data=tips,col='smoker') #for seperate Plots

# %%
sns.relplot('total_bill','tip',data=tips,hue='smoker',col='sex')

# %%
sns.relplot('total_bill','tip',data=tips,hue='smoker',style='smoker')

# %%
sns.scatterplot('total_bill','tip',data=tips)

# %%
sns.relplot('total_bill','tip',data=tips,kind='line')

# %%
sns.relplot('total_bill','tip',data=tips,kind='scatter')

# %% [markdown]
# ## Categorical Plots:

# %%
sns.catplot('day','tip',data=tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot('time','tip',data=tips) #based on time

# %%
sns.catplot('day','tip',data=tips,kind='swarm') #swarm kind

# %%
sns.catplot('day','tip',data=tips,kind='swarm',hue='smoker')

# %%
sns.catplot('day','tip',data=tips,kind='swarm',hue='smoker',col='sex')

# %%
sns.catplot('sex','total_bill',data=tips,kind='swarm')

# %% [markdown]
# ### BOX PLOT:

# %%
sns.catplot('day','tip',data=tips,kind='box')

# %%
sns.catplot('day','tip',data=tips,kind='box',hue='smoker')

# %%
sns.catplot('day','tip',data=tips,kind='box',hue='smoker',col='sex')

# %% [markdown]
# ### COUNT:

# %%
#count
sns.catplot('day',data=tips,kind='count',hue='smoker') #count takes only one data value

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#hue order--> to change the placement of the graphs
sns.catplot('day',data=tips,kind='count',hue='smoker',hue_order=['No','Yes'])

# %%
sns.boxplot(tips['tip'])

# %%
sns.boxplot(y=tips['tip']) #to display vertically

# %%
sns.catplot('day',data=tips,kind='count',hue='smoker')

# %%
sns.countplot(tips['day'])

# %% [markdown]
# ### DISTRIBUTION Plot:

# %%
sns.distplot(tips['tip'])

# %%
sns.distplot(tips['tip'],kde=False)

# %%
sns.distplot(tips['tip'],hist=False)

# %%
sns.distplot(tips['tip'],rug=True,hist=False)

# %%
sns.distplot(tips['tip'],rug=True)

# %% [markdown]
# ### Joint Plot:

# %%
sns.jointplot('total_bill','tip',data=tips)
#x-axis --> total bill
#y-axis --> Tips

# %%
sns.jointplot('total_bill','tip',data=tips,kind='kde') #default==hist

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# - relplot
# - scatter plot
#
#
#     only 'tip','total_bill','size' are numerical columns.
# there will be 3c2 i.e. 6 combinations with these three columns

# %%
tips.dtypes!='category' #returns True For numerical columns and False for else
# Out:
# total_bill     True
# tip            True
# sex           False
# smoker        False
# day           False
# time          False
# size           True
# dtype: bool

# %%
num_col=tips.columns[tips.dtypes!='category']
for i in range(len(num_col)):
    for j in range(len(num_col)):
        print(num_col[i],num_col[j])
# Out:
# total_bill total_bill
# total_bill tip
# total_bill size
# tip total_bill
# tip tip
# tip size
# size total_bill
# size tip
# size size

# %%
val=1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        plt.subplot(3,3,val)
        plt.plot(tips[num_col[i]],tips[num_col[j]])
        plt.title(num_col[i]+'_'+num_col[j])
        val+=1

# %%
val=1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        plt.subplot(3,3,val)
        plt.scatter(tips[num_col[i]],tips[num_col[j]])
        plt.title(num_col[i]+'_'+num_col[j])
        val+=1

# %% [markdown]
# ### Pair Plot:
# for plotting PairWise realtions between two column values for all the features in the data

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='smoker')

# %% [markdown]
# ### Regplot()--> Regression Plot

# %%
sns.regplot('tip','total_bill',data=tips)

# %%
sns.pairplot(tips,hue='smoker',kind='reg')

# %% [markdown]
# #### Correlation Coefficient:
# the realtionship coefficient between X-axis and Y-axis

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
# to set grid
sns.set(style='whitegrid')
sns.pairplot(tips,hue='smoker',kind='reg')
